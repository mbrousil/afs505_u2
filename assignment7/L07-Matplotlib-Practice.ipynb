# %% [markdown]
# # Lesson 7 Practice: Matplotlib
#
# Use this notebook to follow along with the lesson in the corresponding lesson notebook: [L07-Matplotlib-Lesson.ipynb](./L07-Matplotlib-Lesson.ipynb).

# %% [markdown]
# ## Instructions
# Follow along with the teaching material in the lesson. Throughout the tutorial sections labeled as "Tasks" are interspersed and indicated with the icon: ![Task](http://icons.iconarchive.com/icons/sbstnblnd/plateau/16/Apps-gnome-info-icon.png). You should follow the instructions provided in these sections by performing them in the practice notebook.  When the tutorial is completed you can turn in the final practice notebook. For each task, use the cell below it to write and test your code.  You may add additional cells for any task as needed or desired.

# %% [markdown]
# ## Task 1a: Setup
#
# Import the following packages:
# + `pandas` as `pd`
# + `numpy` as `np`
# + `matplotlib.pyplot` as `plt`
#
# Activate the `%matplotlib inline` magic.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Task 1b: Load Data
#
# Load the Iris data (same as in the Pandas tasks).

# %%
iris_df = pd.read_csv("../data/iris.csv")
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Task 2a: Create a figure
#
# Create the a scatter plot using the iris data, but compare `petal_width` to `petal_length`.  Be sure to add labels to the axes.

# %%
fig_base = plt.figure()
fig_base_plot = fig_base.add_subplot(1, 1, 1)
fig_base_plot.scatter(iris_df["petal_width"], iris_df["petal_length"])

fig_base_plot.axes.set_xlabel("Petal Width")
fig_base_plot.axes.set_ylabel("Petal Length")

plt.show()

# %% [markdown]
# ## Task 3a: Figure Style
#
# Create a scatter plots using the iris data frame. Do not convert the data frame columns to numpy arrays. Rather use the dataframe as is. Be sure to:
# - plot `petal_length` vs `petal_width`.
# - Use column names to specify the x and y coordinates (don't pass in Numpy arrays)
# - Color each dot by the species (you'll need to be creative to do this).
#   - Hint 1: use the [pd.Series.replace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) function to convert species names to colors).
#   - Hint 2: Use the color abbreviations we learned for the the plot function (e.g. 'r', 'b', 'g', etc.).
# - Add axis labels

# %%
iris_df_col = iris_df
iris_df_col["color"] = iris_df_col["species"]
iris_df_col["color"].replace("setosa", "r", inplace = True)
iris_df_col["color"].replace("virginica", "b", inplace = True)
iris_df_col["color"].replace("versicolor", "m", inplace = True)

iris_df_col.head()

scatter_plot = plt.figure()
scatter_base = scatter_plot.add_subplot(1, 1, 1)
scatter_base.scatter(x = "petal_length", y = "petal_width", c = "color", data = iris_df)
scatter_base.axes.set_ylabel("Petal width")
scatter_base.axes.set_xlabel("Petal length")
# Out:
# Text(0.5, 0, 'Petal length')

# %% [markdown]
# ## Task 4a: Categorical plots
#
# Create a bar graph that indicates the mean `sepal_length` of each subspecies.

# %%
bar_base = plt.figure()
bar_fig = bar_base.add_subplot(1, 1, 1)
bar_fig.bar(x = "species", height = "sepal_length", data = iris_df)
# Out:
# <BarContainer object of 150 artists>

# %% [markdown]
# ## Task 6a:  Multiple Plots
#
# Create 4 scatterplots for the iris data all in one figure. The figure should include scatterplots of these comparisions:
# - `sepal_length` x `petal_length`
# - `sepal_length` x `petal_width`
# - `sepal_width` x `petal_length`
# - `sepal_width` x `petal_width`
#
# Be sure that:
# - the points for the species
# - the axes for each plot are labeled
# - the figure has a label.

# %%
iris_scatter = plt.figure()
iris_plots = iris_scatter.subplots(2, 2)
iris_plots[0, 0].scatter(x = "sepal_length", y = "petal_length", c = "color", data = iris_df_col)
iris_plots[0, 0].axes.set_xlabel('Sepal Length')
iris_plots[0, 0].axes.set_ylabel('Petal Length')

iris_plots[0, 1].scatter(x = "sepal_length", y = "petal_width", c = "color", data = iris_df_col)
iris_plots[0, 1].axes.set_xlabel('Sepal Length')
iris_plots[0, 1].axes.set_ylabel('Petal Width')

iris_plots[1, 0].scatter(x = "sepal_width", y = "petal_length", c = "color", data = iris_df_col)
iris_plots[1, 0].axes.set_xlabel('Sepal Width')
iris_plots[1, 0].axes.set_ylabel('Petal Length')

iris_plots[1, 1].scatter(x = "sepal_width", y = "petal_width", c = "color", data = iris_df_col)
iris_plots[1, 1].axes.set_xlabel('Sepal Width')
iris_plots[1, 1].axes.set_ylabel('Petal Width')

iris_scatter.suptitle("Iris measurement comparisons")

# iris_scatter.tight_layout()
# Out:
# Text(0.5, 0.98, 'Iris measurement comparisons')
